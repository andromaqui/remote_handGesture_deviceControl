# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("A0.jpg")[...,::-1]/255.0
noise =  np.random.normal(loc=0, scale=1, size=img.shape)

# noise overlaid over image
noisy = np.clip((img + noise*0.2),0,1)
noisy2 = np.clip((img + noise*0.4),0,1)

# noise multiplied by image:
# whites can go to black but blacks cannot go to white
noisy2mul = np.clip((img*(1 + noise*0.2)),0,1)
noisy4mul = np.clip((img*(1 + noise*0.4)),0,1)

noisy2mul = np.clip((img*(1 + noise*0.2)),0,1)
noisy4mul = np.clip((img*(1 + noise*0.4)),0,1)

# noise multiplied by bottom and top half images,
# whites stay white blacks black, noise is added to center
img2 = img*2
n2 = np.clip(np.where(img2 <= 1, (img2*(1 + noise*0.2)), (1-img2+1)*(1 + noise*0.2)*-1 + 2)/2, 0,1)
n4 = np.clip(np.where(img2 <= 1, (img2*(1 + noise*0.4)), (1-img2+1)*(1 + noise*0.4)*-1 + 2)/2, 0,1)


# norm noise for viz only
noise2 = (noise - noise.min())/(noise.max()-noise.min())
plt.figure(figsize=(20,20))
plt.imshow(np.vstack((np.hstack((img, noise2)),
                      np.hstack((noisy, noisy2)),
                      np.hstack((noisy2mul, noisy4mul)),
                      np.hstack((n2, n4)))))
plt.show()
plt.hist(noise.ravel(), bins=100)
plt.show()

# %%
import albumentations as A

# %%
# Read an image with OpenCV and convert it to the RGB colorspace
image1 = cv2.imread("A0.jpg")
image1 = cv2.resize(image1, (128, 128)) #R
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)

# Read an image with OpenCV and convert it to the RGB colorspace
image2 = cv2.imread("B4.jpg")
image2 = cv2.resize(image2, (128, 128)) #R
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# Read an image with OpenCV and convert it to the RGB colorspace
image8 = cv2.imread("B5.jpg")
image8 = cv2.resize(image8, (128, 128)) #R
image8 = cv2.cvtColor(image8, cv2.COLOR_BGR2RGB)

# Read an image with OpenCV and convert it to the RGB colorspace
image3 = cv2.imread("B7.jpg")
image3 = cv2.resize(image3, (128, 128)) #R
image3 = cv2.cvtColor(image3, cv2.COLOR_BGR2RGB)

# Read an image with OpenCV and convert it to the RGB colorspace
image4 = cv2.imread("B8.jpg")
image4 = cv2.resize(image4, (128, 128)) #R
image4 = cv2.cvtColor(image4, cv2.COLOR_BGR2RGB)

# Read an image with OpenCV and convert it to the RGB colorspace
image5 = cv2.imread("B60.jpg")
image5 = cv2.resize(image5, (128, 128)) #R
image5 = cv2.cvtColor(image5, cv2.COLOR_BGR2RGB)

# Read an image with OpenCV and convert it to the RGB colorspace
image6 = cv2.imread("B405.jpg")
image6 = cv2.resize(image6, (128, 128)) #R
image6 = cv2.cvtColor(image6, cv2.COLOR_BGR2RGB)

# Read an image with OpenCV and convert it to the RGB colorspace
image7 = cv2.imread("B261.jpg")
image7 = cv2.resize(image7, (128, 128)) #R
image7 = cv2.cvtColor(image7, cv2.COLOR_BGR2RGB)

# %%
import numpy as np
import matplotlib.pyplot as plt

def gallery(array, ncols=3):
    nindex, height, width, intensity = array.shape
    nrows = nindex//ncols
    assert nindex == nrows*ncols
    # want result.shape = (height*nrows, width*ncols, intensity)
    result = (array.reshape(nrows, ncols, height, width, intensity)
              .swapaxes(1,2)
              .reshape(height*nrows, width*ncols, intensity))
    return result

#result = gallery(array)
#plt.imshow(result)
#plt.show()

def show_image(image):
    f = plt.figure(figsize=(18, 12))
    plt.imshow(
      cv2.cvtColor(image, cv2.COLOR_BGR2RGB),
      interpolation='nearest'
    )
    plt.axis('off')
    f.tight_layout()
    plt.show()

# %%
# Declare an augmentation pipeline
transform = A.Compose([
    A.RandomCrop(width=128, height=128),
    #A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=1),
])

# Read an image with OpenCV and convert it to the RGB colorspace
image = cv2.imread("A0.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Augment an image
transformed1 = transform(image=image1)
transformed_image1 = transformed["image"]

transformed2 = transform(image=image2)
transformed_image2 = transformed2["image"]

transformed3 = transform(image=image3)
transformed_image3 = transformed3["image"]

transformed4 = transform(image=image4)
transformed_image4 = transformed4["image"]

transformed5 = transform(image=image5)
transformed_image5 = transformed5["image"]

transformed6 = transform(image=image6)
transformed_image6 = transformed6["image"]

transformed7 = transform(image=image7)
transformed_image7 = transformed7["image"]

transformed8 = transform(image=image8)
transformed_image8 = transformed8["image"]

array1 = np.array([transformed_image1, transformed_image2,transformed_image3
                  ,transformed_image4,transformed_image5, transformed_image6
                  ,transformed_image7, transformed_image8, transformed_image8 ])

result = gallery(array1)
plt.imshow(result)
plt.show()



#show_image(transformed_image)

# %%
# Declare an augmentation pipeline
transform = A.Compose([
    A.RandomCrop(width=128, height=128),
    #A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=1, always_apply=True),
])

# Read an image with OpenCV and convert it to the RGB colorspace
image = cv2.imread("A0.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Augment an image
transformed1 = transform(image=image1)
transformed_image1 = transformed["image"]

transformed2 = transform(image=image2)
transformed_image2 = transformed2["image"]

transformed3 = transform(image=image3)
transformed_image3 = transformed3["image"]

transformed4 = transform(image=image4)
transformed_image4 = transformed4["image"]

transformed5 = transform(image=image5)
transformed_image5 = transformed5["image"]

transformed6 = transform(image=image6)
transformed_image6 = transformed6["image"]

transformed7 = transform(image=image7)
transformed_image7 = transformed7["image"]

transformed8 = transform(image=image8)
transformed_image8 = transformed8["image"]


array1 = np.array([transformed_image1, transformed_image2,transformed_image3
                  ,transformed_image4,transformed_image5, transformed_image6
                  ,transformed_image7, transformed_image8, transformed_image8 ])

result = gallery(array1)
plt.imshow(result)
plt.show()

# %%
# Declare an augmentation pipeline
transform = A.Compose([
           A.RandomGamma(gamma_limit=(200, 300), always_apply=True)

])

# Augment an image
transformed1 = transform(image=image1)
transformed_image1 = transformed["image"]

transformed2 = transform(image=image2)
transformed_image2 = transformed2["image"]

transformed3 = transform(image=image3)
transformed_image3 = transformed3["image"]

transformed4 = transform(image=image4)
transformed_image4 = transformed4["image"]

transformed5 = transform(image=image5)
transformed_image5 = transformed5["image"]

transformed6 = transform(image=image6)
transformed_image6 = transformed6["image"]

transformed7 = transform(image=image7)
transformed_image7 = transformed7["image"]

transformed8 = transform(image=image8)
transformed_image8 = transformed8["image"]


array1 = np.array([transformed_image1, transformed_image2,transformed_image3
                  ,transformed_image4,transformed_image5, transformed_image6
                  ,transformed_image7, transformed_image8, transformed_image8 ])
result = gallery(array1)
plt.imshow(result)
plt.show()

# %%
# Declare an augmentation pipeline
transform = A.Compose([
           A.RandomGamma(gamma_limit=(100, 200), always_apply=True)

])

# Augment an image
transformed1 = transform(image=image1)
transformed_image1 = transformed["image"]

transformed2 = transform(image=image2)
transformed_image2 = transformed2["image"]

transformed3 = transform(image=image3)
transformed_image3 = transformed3["image"]

transformed4 = transform(image=image4)
transformed_image4 = transformed4["image"]

transformed5 = transform(image=image5)
transformed_image5 = transformed5["image"]

transformed6 = transform(image=image6)
transformed_image6 = transformed6["image"]

transformed7 = transform(image=image7)
transformed_image7 = transformed7["image"]

transformed8 = transform(image=image8)
transformed_image8 = transformed8["image"]


array1 = np.array([transformed_image1, transformed_image2,transformed_image3
                  ,transformed_image4,transformed_image5, transformed_image6
                  ,transformed_image7, transformed_image8, transformed_image8 ])
result = gallery(array1)
plt.imshow(result)
plt.show()

# %%
# Declare an augmentation pipeline
transform = A.Compose([
           A.GaussNoise(var_limit=(600.0, 700.0), mean=0, always_apply=True, p=1)
])

# Augment an image
transformed1 = transform(image=image1)
transformed_image1 = transformed["image"]

transformed2 = transform(image=image2)
transformed_image2 = transformed2["image"]

transformed3 = transform(image=image3)
transformed_image3 = transformed3["image"]

transformed4 = transform(image=image4)
transformed_image4 = transformed4["image"]

transformed5 = transform(image=image5)
transformed_image5 = transformed5["image"]

transformed6 = transform(image=image6)
transformed_image6 = transformed6["image"]

transformed7 = transform(image=image7)
transformed_image7 = transformed7["image"]

transformed8 = transform(image=image8)
transformed_image8 = transformed8["image"]


array1 = np.array([transformed_image1, transformed_image2,transformed_image3
                  ,transformed_image4,transformed_image5, transformed_image6
                  ,transformed_image7, transformed_image8, transformed_image8 ])
result = gallery(array1)
plt.imshow(result)
plt.show()

# %%
# Declare an augmentation pipeline
transform = A.Compose([
        A.RandomGamma(gamma_limit=(400, 500), always_apply=True)
])

# Read an image with OpenCV and convert it to the RGB colorspace
image = cv2.imread("C5.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Augment an image
transformed = transform(image=image)
transformed_image = transformed["image"]

show_image(transformed_image)
